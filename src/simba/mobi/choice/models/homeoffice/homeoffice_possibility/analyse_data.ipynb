# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_folder = '/media/nicolas-salvade/Windows/Users/DAF1/OneDrive - University College London/Documents/PhD - UCL/choice_set_location_travelmode/Data/mtmc/'
individuals_path = data_folder + 'target_indiv.csv'
households_path = data_folder + 'household.csv'

# %%
df_p = pd.read_csv(individuals_path)
df_h = pd.read_csv(households_path)

# %%
df_p
# Out:
#          HHNR  age  interv_lang  day_week  dl_car  dl_moto  learning_car  \
# 0      100004   50            1         3       1        1           -99
# 1      100010    8            3         6     -99      -99           -99
# 2      100021   68            1         6       1        2           -99
# 3      100028   61            2         1       1        2           -99
# 4      100037   30            2         6       2        2             2
# ...       ...  ...          ...       ...     ...      ...           ...
# 57085  499969   15            2         7     -99      -99           -99
# 57086  499994   10            1         7     -99      -99           -99
# 57087  499995   48            3         5       1        1           -99
# 57088  499996   68            1         7       1        2           -99
# 57089  499998   63            1         7       1        2           -99
#
#        learning_moto  park_work_car  park_edu_car  ...  edu_y_CH1903  \
# 0                -99            -99           -99  ...           -99
# 1                -99            -99           -99  ...        119287
# 2                  2            -99           -99  ...           -99
# 3                  2            -99           -99  ...           -99
# 4                  2            -99           -99  ...           -99
# ...              ...            ...           ...  ...           ...
# 57085            -99            -99           -99  ...        117449
# 57086            -99            -99           -99  ...        227383
# 57087            -99            -99           -99  ...           -99
# 57088              2            -99           -99  ...           -99
# 57089              2            -99           -99  ...           -99
#
#        edu_country  edu_lang  edu_region  edu_canton  edu_npa  edu_agglo2012  \
# 0              -99       -99         -99         -99      -99            -99
# 1             8100         3           7          21     6517           5002
# 2              -99       -99         -99         -99      -99            -99
# 3              -99       -99         -99         -99      -99            -99
# 4              -99       -99         -99         -99      -99            -99
# ...            ...       ...         ...         ...      ...            ...
# 57085         8100         2           1          25     1204           6621
# 57086         8100         1           6           3     6277              0
# 57087          -99       -99         -99         -99      -99            -99
# 57088          -99       -99         -99         -99      -99            -99
# 57089          -99       -99         -99         -99      -99            -99
#
#        edu_agglo_groesse2012  edu_urban_char_2012  edu_stat_city_2012
# 0                        -99                  -99                 -99
# 1                          4                    2                   0
# 2                        -99                  -99                 -99
# 3                        -99                  -99                 -99
# 4                        -99                  -99                 -99
# ...                      ...                  ...                 ...
# 57085                      1                    1                   1
# 57086                      0                    0                   0
# 57087                    -99                  -99                 -99
# 57088                    -99                  -99                 -99
# 57089                    -99                  -99                 -99
#
# [57090 rows x 96 columns]
